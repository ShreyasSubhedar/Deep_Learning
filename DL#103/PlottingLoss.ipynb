# %% [markdown]
# #Compute Loss of Given DataSet

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

def sigmoid(x,w,b):
  return 1/(1+np.exp(-(w*x+b)))

# %%
w_unknown=0.5
b_unknown= 0.25
X= np.random.random(25)*20-10
Y = sigmoid(X,w_unknown,b_unknown)

# %% [markdown]
# The points that we have with us

# %%
plt.plot(X,Y,'*')
plt.show()

# %% [markdown]
# Now we need to find the W And B which give us min

# %%
def cal_loss(X,Y,w_est,b_est):
  loss=0
  for x,y in zip(X,Y):
    loss += (y-sigmoid(x,w_est,b_est))**2
  return loss

# %%
W = np.linspace(0,2,100)  # cahnging the range as -ve w is leading towards higher loss value
B =np.linspace(-1,1,100)
WW, BB = np.meshgrid(W,B)
Loss= np.zeros(WW.shape)

# %%
WW.shape
# Out:
# (100, 100)

# %%
for i in range(WW.shape[0]):
  for j in range(WW.shape[1]):
    Loss[i,j]=cal_loss(X,Y,WW[i,j],BB[i,j])

# %% [markdown]
# #3D plot

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_surface(WW, BB, Loss, cmap='viridis')
ax.set_xlabel('w')
ax.set_ylabel('b')
ax.set_zlabel('loss')

plt.show()

# %%
ij=np.argmin(Loss)
i=int(np.floor(ij/Loss.shape[1]))
j = int(ij-i*Loss.shape[1])

# %%
print(WW[i][j],BB[i][j])
# Out:
# 0.5050505050505051 0.2525252525252526
