# %% [markdown]
# #SIgmoid Function 3D Plot

# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

def sigmoid_2d(x1,x2,w1,w2,b):
  return 1/(1+np.exp(-(w1*x1+w2*x2+b)))

# %%
print(sigmoid_2d(1,0,0.5,0,0))
# Out:
# 0.6224593312018546

# %%
x1 =np.linspace(-10,10,100)
x2=np.linspace(-10,10,100)
XX1,XX2=np.meshgrid(x1,x2)
w1=0.5
w2=2
b=1
Y=sigmoid_2d(XX1,XX2,w1,w2,b)

# %% [markdown]
# #3D plot

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_surface(Y,XX1, XX2, cmap='viridis')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')

plt.show()

# %% [markdown]
# #TOP view of the 3d plot

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_surface(XX1, XX2, Y, cmap='viridis')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
ax.view_init(90,0)
plt.show()

# %% [markdown]
# #Conclusion
# If more the weight value more the dominance of that feature
#
#
# ---
#
# The top view can help analyze the the model on the basis of regression with respect to probability.
